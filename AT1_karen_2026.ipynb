# %% [markdown]
# <a href="https://colab.research.google.com/github/karenifesengcivil192-cyber/ALGESTDADOS20261/blob/main/AT1_karen_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
nome="Karen"
idade= 18

print(f"meu nome é {nome} e tenho {idade} anos de idade")
# Out:
# meu nome é Karen e tenho 18 anos de idade

# %%
#2
nome="Karen"
print(f"Bem vindo(a), {nome}!")
# Out:
# Bem vindo(a), Karen!

# %%
#3
num1= 2
num2= 5
soma= num1 + num2

print(f"{num1} + {num2} = {soma}")
# Out:
# 2 + 5 = 7

# %%
#4
num= 5
ant= num - 1
suc= num + 1

print(f"O antecessor de {num} é {ant}")
print(f"O sucessor de {num} é {suc}")
# Out:
# O antecessor de 5 é 4
# O sucessor de 5 é 6

# %%
#5
num1= int(input("Digite o ano do seu nascimento:"))
num2= int(input("Digite o ano atual:"))
idade= num2 - num1

print(f"Sua idade é {idade}")
# Out:
# Digite o ano do seu nascimento:2008
# Digite o ano atual:2026
# Sua idade é 18

# %%
#6
num1= 3
num2= 5
med= (num1 + num2) / 2

print(f"A média entre {num1} e {num2} é {med}")
# Out:
# A média entre 3 e 5 é 4.0

# %%
#7
cel= float(input("Digite a temperatura em graus Celsius:"))
far= (cel * 1.8) + 32

print(f"A temperatura em graus Fahrenheit é {far}")
# Out:
# Digite a temperatura em graus Celsius:25
# A temperatura em graus Fahrenheit é 77.0

# %%
#8
altura= 4
largura= 8
area= altura * largura

print(f"A área do retângulo é {area}m²")
# Out:
# A área do retângulo é 32m²

# %%
#9
num= int(input("Digite o número:"))
quadrado= num * num

print(f"O quadrado de {num} é {quadrado}")
# Out:
# Digite o número:4
# O quadrado de 4 é 16

# %%
#10
num1 = input("Digite o primeiro número:")
operacao = input("Digite a operação (+, -, *, /):")
num2 = input("Digite o segundo número:")

resultado = eval(num1 + operacao + num2)

print(f"O resultado da conta é {resultado}")
# Out:
# Digite o primeiro número:5
# Digite a operação (+, -, *, /):+
# Digite o segundo número:5
# O resultado da conta é 10
