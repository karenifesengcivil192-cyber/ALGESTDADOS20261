# %% [markdown]
# <a href="https://colab.research.google.com/github/karenifesengcivil192-cyber/ALGESTDADOS20261/blob/main/EXERCICIOS_FIXACAO/atv2303_2603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ATIVIDADE 1
nota = float(input("Digite a nota: "))

if nota >= 9:
    print("A — Excelente")
elif nota >= 7:
    print("B — Aprovado")
elif nota >= 5:
    print("C — Recuperação")
else:
    print("D — Reprovado")
# Out:
# Digite a nota: 8
# B — Aprovado

# %%
# ATIVIDADE 2
numero = int(input("Digite um número de 1 a 7: "))

if numero == 1:
    print("O Dia é Segunda-feira")
elif numero == 2:
    print("O Dia é Terça-feira")
elif numero == 3:
    print("O Dia é Quarta-feira")
elif numero == 4:
    print("O Dia é Quinta-feira")
elif numero == 5:
    print("O Dia é Sexta-feira")
elif numero == 6:
    print("O Dia é Sábado")
elif numero == 7:
    print("O Dia é Domingo")
else:
    print("Dia inválido")
# Out:
# Digite um número de 1 a 7: 4
# O Dia é Quinta-feira

# %%
# ATIVIDADE 3
nota = float(input("Digite a nota: "))

if 0 <= nota <= 10:
    print(f"Nota registrada: {nota}")
else:
    print("Nota inválida!")
# Out:
# Digite a nota: -9
# Nota inválida!

# %%
# ATIVIDADE 4
idade = int(input("Digite a idade: "))

if idade < 0:
    print("Idade inválida")
elif idade < 12:
    print("Criança")
elif idade <= 17:
    print("Adolescente")
elif idade <= 59:
    print("Adulto")
else:
    print("Idoso")
# Out:
# Digite a idade: 18
# Adulto

# %%
# ATIVIDADE 5
print("Menu:")
print("1 - Água R$2")
print("2 - Suco R$6")
print("3 - Café R$4")

item = int(input("Escolha um item: "))

if not (1 <= item <= 3):
    print("Opção inválida")
elif item == 1:
    print("Água - R$2")
elif item == 2:
    print("Suco - R$6")
else:
    print("Café - R$4")
# Out:
# Menu:
# 1 - Água R$2
# 2 - Suco R$6
# 3 - Café R$4
# Escolha um item: 2
# Suco - R$6

# %%
# ATIVIDADE 6
temp = float(input("Digite a temperatura em °C: "))

if temp < 0:
    print("A temperatura está Congelante")
elif temp <= 15:
    print("A temperatura está Fria")
elif temp <= 25:
    print("A temperatura está Agradável")
elif temp <= 35:
    print("A temperatura está Quente")
else:
    print("A temperatura está Muito quente")
# Out:
# Digite a temperatura: 26
# Quente

# %%
# ATIVIDADE 7
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
op = input("Digite o operador (+, -, *, /): ")

if op == "+":
    print("Resultado:", num1 + num2)
elif op == "-":
    print("Resultado:", num1 - num2)
elif op == "*":
    print("Resultado:", num1 * num2)
elif op == "/":
    if num2 == 0:
        print("Erro: divisão por zero")
    else:
        print("Resultado:", num1 / num2)
else:
    print("Operador desconhecido")
# Out:
# Digite o primeiro número: 3
# Digite o segundo número: 7
# Digite o operador (+, -, *, /): +
# Resultado: 10.0

# %%
# ATIVIDADE 8
usuario_cor = "adm"
senha_cor = "123"

usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == usuario_cor and senha == senha_cor:
    print("Login efetuado!")
else:
    print("Usuário ou senha incorretos.")
# Out:
# Usuário: adm
# Senha: 123
# Login efetuado!

# %%
# ATIVIDADE 9
a = float(input("Lado A: "))
b = float(input("Lado B: "))
c = float(input("Lado C: "))

if a <= 0 or b <= 0 or c <= 0:
    print("Valores inválidos")
elif a < b + c and b < a + c and c < a + b:
    print("Forma um triângulo")
else:
    print("Não forma um triângulo")
# Out:
# Lado A: 4
# Lado B: 3
# Lado C: 5
# Forma um triângulo

# %%
# ATIVIDADE 10
valor = float(input("Valor da compra: "))

if valor <= 0:
    print("Valor inválido")
elif valor >= 500:
    desconto = 0.15
elif valor >= 200:
    desconto = 0.10
elif valor >= 100:
    desconto = 0.05
else:
    desconto = 0

valor_final = valor * (1 - desconto)
print(f"Desconto: {desconto*100}%")
print(f"Valor final: R${valor_final:.2f}")
# Out:
# Valor da compra: 150
# Desconto: 5.0%
# Valor final: R$142.50

# %%
# ATIVIDADE 11
mes = int(input("Digite o mês (1 a 12): "))

if mes < 1 or mes > 12:
    print("Mês inválido")
elif mes == 12 or mes == 1 or mes == 2:
    print("Verão")
elif mes == 3 or mes == 4 or mes == 5:
    print("Outono")
elif mes == 6 or mes == 7 or mes == 8:
    print("Inverno")
else:
    print("Primavera")
# Out:
# Digite o mês (1 a 12): 9
# Primavera

# %%
# ATIVIDADE 12
A = float(input("Digite A: "))
B = float(input("Digite B (maior que A): "))
N = float(input("Digite N: "))

if A <= N <= B:
    print("N está dentro do intervalo")
else:
    print("N está fora do intervalo")
# Out:
# Digite A: 1
# Digite B (maior que A): 10
# Digite N: 5
# N está dentro do intervalo

# %%
# ATIVIDADE 13
num = int(input("Digite um número inteiro: "))
if num == 0:
    print("O número é zero")
elif num % 2 == 0 and num > 0:
        print("O número é par e positivo")
elif num % 2 == 0 and num < 0:
        print("O número é par e negativo")
elif num % 2 != 0 and num > 0:
        print("O número é ímpar e positivo")
else:
        print("O número é ímpar e negativo")
# Out:
# Digite um número inteiro: -17
# O número é ímpar e negativo

# %%
# ATIVIDADE 14
nota = float(input("Digite sua nota: "))
freq = float(input("Digite sua frequência(%): "))

if nota >= 7 and freq >= 75:
    print("Você foi aprovado(a), Parabéns!")
elif nota <7 and freq >= 75:
    print("Você está em recuperação, mas sua frequência está correta!")
elif nota >= 7 and freq < 75:
    print("Você está com boas notas, mas sua frequência está incorreta!")
else:
    print("Você está reprovado(a8)!")
# Out:
# Digite sua nota: 10
# Digite sua frequência(%): 80
# Você foi aprovado(a), Parabéns!

# %%
# ATIVIDADE 15
peso = float(input("Digite seu peso: "))
alt = float(input("Digite sua altura: "))
imc = peso / (alt ** 2)

if imc < 18.5:
    print("Você está abaixo do peso")
elif imc >= 18.5 and imc <= 24.9:
    print("Você está no peso ideal")
elif imc >= 25 and imc <= 29.9:
    print("Você está com sobrepeso")
else:
    print("Você está com obesidade")
# Out:
# Digite seu peso: 70
# Digite sua altura: 1.70
# Você está no peso ideal
