# %% [markdown]
# <a href="https://colab.research.google.com/github/karenifesengcivil192-cyber/ALGESTDADOS20261/blob/main/EXERCICIOS_FIXACAO/AULA12/03_16/03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= float(input("Digite o primeiro número:"))
b= float(input("Digite o segundo número:"))

print(f"\na soma é: ", (a+b))
print(f"a subtração é: ", (a-b))
print(f"a multiplicação é: ", (a*b))
print(f"a divisão real é: ", (a/b))
print(f"a divisão inteira é: ", (a//b))
print(f"o  módulo é: ", (a%b))
print(f"a potenciação é: ", (a**b))
# Out:
# Digite o primeiro número:10
# Digite o segundo número:3
#
# a soma é:  13.0
# a subtração é:  7.0
# a multiplicação é:  30.0
# a divisão real é:  3.3333333333333335
# a divisão inteira é:  3.0
# o  módulo é:  1.0
# a potenciação é:  1000.0

# %%
nota= float(input("Digite sua nota:"))
print(nota >= 6.0)
print(nota == 10.0)
print(nota != 5.0)
print(nota < 5.0)
# Out:
# Digite sua nota:7.5
# True
# False
# True
# False

# %%
idade= int(input("Digite sua idade:"))
renda= float(input("Digite sua renda:"))

print(idade >= 18 and renda >= 1200)
print(idade >= 18 or renda >= 1200)

tem_debito= False
print(not tem_debito)
# Out:
# Digite sua idade:17
# Digite sua renda:1500
# False
# True
# True

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2)
print(10 / 2 + 3)
print(10 / (2 + 3))

x = 3 + 2 * 4 > 10 and not False
print(x)
# Out:
# 14
# 20
# 512
# 8.0
# 2.0
# True

# %%
#ATIVIDADE 1
a= 15
b= 4

print(f"\na soma é: ", (a+b))
print(f"a subtração é: ", (a-b))
print(f"a multiplicação é: ", (a*b))
print(f"a divisão real é: ", (a/b))
print(f"a divisão inteira é: ", (a//b))
print(f"o  módulo é: ", (a%b))
print(f"a potenciação é: ", (a**b))
# Out:
# a soma é:  19
# a subtração é:  11
# a multiplicação é:  60
# a divisão real é:  3.75
# a divisão inteira é:  3
# o  módulo é:  3
# a potenciação é:  50625

# %%
#ATIVIDADE 2
alunos= int(input("Digite a quantidade de alunos:"))
grup= int(input("Digite a quantidade de alunos por grupo:"))
print(f"a quantidade de grupos completos é: ", (alunos//grup))
print(f"a quantidade de alunos que sobrarão é: ", (alunos%grup))
# Out:
# Digite a quantidade de alunos:37
# Digite a quantidade de alunos por grupo:5
# a quantidade de grupos completos é:  7
# a quantidade de alunos que sobrarão é:  2

# %%
#ATIVIDADE 3
base= float(input("Digite a base do retângulo:"))
altura= float(input("Digite a altura do retângulo:"))
print(f"a área do retângulo é: {base * altura:.2f}")
# Out:
# Digite a base do retângulo:8.5
# Digite a altura do retângulo:3.2
# a área do retângulo é:  27.20

# %%
#ATIVIDADE 4
segundos = int(input("Digite a quantidade de segundos:"))
horas= segundos // 3600
resto= segundos % 3600
minutos= resto // 60
seg= resto % 60
print(f"{horas}h {minutos}min e {seg}seg")
# Out:
# Digite a quantidade de segundos:9875
# 2h 44min e 35seg

# %%
#ATIVIDADE 5
resul= 2 ** 10
print(f"2 elevado a 10 é:", (resul))
print("** significa potenciação em Phyton")

raiz= 144 ** 0.5
print(f"\na raiz quadrada de 144 é:", (raiz))
# Out:
# 2 elevado a 10 é: 1024
# ** significa potenciação em Phyton
#
# a raiz quadrada de 144 é: 12.0

# %%
#ATIVIDADE 6
temp= 38.5
print(temp>37.5)
print(temp==36.5)
print(temp!=40)
# Out:
# True
# False
# True

# %%
#ATIVIDADE 7
x = 10
y = 10

print(x == y) #True
print(x != y) #False
print(x >= y) #True
print(x <= y + 1) #True
# Out:
# True
# False
# True
# True

# %%
#ATIVIDADE 8
nota= float(input("Digite sua nota:"))
print(f"ele foi aprovado?", nota >= 7.0)
print(f"ele está de recuperação?", (nota < 7.0)and(nota >= 5.0))
print(f"ele foi reprovado?", nota < 5.0)
# Out:
# Digite sua nota:6.5
# ele foi aprovado? False
# ele está de recuperação? True
# ele foi reprovado? False

# %%
#ATIVIDADE 9
a = 5
b = "5"
print(a == b)
#False pois o A está em texto e o B está em string
# Out:
# False

# %%
#ATIVIDADE 10
preco =float(input("Digite o preço do produto: "))
print(f"o preço está dentro do orçamento?", preco <= 50)
# Out:
# Digite o preço do produto: 49
# o preço está dentro do orçamento? True

# %%
#ATIVIDADE 11
idade = int(input("Digite sua idade: "))
print("Você pode votar?", idade >= 16)
# Out:
# Digite sua idade: 16
# Você pode votar? True

# %%
#ATIVIDADE 12
renda = float(input("Digite sua renda: "))
score = float(input("Digite seu score: "))
print(f"minha renda é", (renda), "e meu score é", (score))
print("Empréstimo aprovado?", renda >= 2000 and score >= 700)
# Out:
# Digite sua renda: 2500
# Digite seu score: 720
# minha renda é 2500.0 e meu score é 720.0
# Empréstimo aprovado? True

# %%
#ATIVIDADE 13
acesso = int(input("Digite seu nível: "))
admin = bool(input("Você é administrador(a)?: "))

print("Acesso liberado?", admin==True or acesso >= 3)
# Out:
# Digite seu nível: 4
# Você é administrador(a)?: False
# Acesso liberado? True

# %%
#ATIVIDADE 14
chovendo = True
temperatura = 30

print(f"Está chovendo?", (not chovendo), "\nE a temperatura é maior que 25°c?",(temperatura > 25))
# Out:
# Está chovendo? False
# E a temperatura é maior que 25°c? True

# %%
#ATIVIDADE 15
print("True and True =", True and True)
print("True and False =", True and False)
print("False and True =", False and True)
print("False and False =", False and False)
# Out:
# True and True = True
# True and False = False
# False and True = False
# False and False = False

# %%
#ATIVIDADE 16
print(5 + 2 * 3)
print((5 + 2) * 3)
print(2 ** 3 ** 2)
print(10 - 4 / 2 + 1)
# Out:
# 11
# 21
# 512
# 9.0

# %%
#ATIVIDADE 17
resultado = 3 + 2 * 4 ** 2 - 1
#1° passso > 4 ** 2
#2° passo > 16 * 2
#3° passo > 3 + 32 - 1
print(resultado)

resultado2= 3 + (2 * (4 ** 2) - 1)
print(resultado2)
# Out:
# 34
# 34

# %%
#ATIVIDADE 18
x = 4 + 3 * 2 > 9 and not (5 == 5)
print(x)
#para a expressão AND ser false, basta que uma das proposições seja false
# Out:
# False

# %%
#ATIVIDADE 19
a= 10 / (2 + 3)
print(a) #Resultado = 2

b= not (True or False)
print(b) #Resultado = False
# Out:
# 2.0
# False

# %%
#ATIVIDADE 20
nota1 = 9.5
nota2 = 8.5
media = (nota1 + nota2) / 2

print(f"Está aprovado? {media >= 9.0 and nota1 >= 7 and nota2 >= 7}")
# Out:
# Está aprovado? True
