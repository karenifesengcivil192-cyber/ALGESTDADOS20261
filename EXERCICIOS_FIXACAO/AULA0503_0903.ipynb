# %% [markdown]
# <a href="https://colab.research.google.com/github/karenifesengcivil192-cyber/ALGESTDADOS20261/blob/main/EXERCICIOS_FIXACAO/AULA0503_0903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 10
y= x
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664

# %%
#exemplo de verificação de erro
x= 0.1 + 0.4
print(x)
# Out:
# 0.5

# %%
x= "Olá mundo!"
print(x)
# Out:
# Olá mundo!

# %%
x= input("Digite seu nome:")
print(x)
# Out:
# Digite seu nome:Karen
# Karen

# %%
print("SISTEMA ANO DE NASCIMENTO")
x= int(input("Digite sua idade:"))
print(2026-x)
# Out:
# SISTEMA ANO DE NASCIMENTO
# Digite sua idade:18
# 2008

# %%
#ATIVIDADE N°1
x= int(input("Digite sua idade:"))
print("Sua idade somada a 5 anos é:")
print(x + 5)
# Out:
# Digite sua idade:18
# Sua idade somada a 5 anos é:
# 23

# %%
#ATIVIDADE N°2
x= float(input("Digite sua altura em metros:"))
print("O dobro da sua altura é:")
print(x * 2)
# Out:
# Digite sua altura em metros:1.66
# O dobro da sua altura é:
# 3.32

# %%
#ATIVIDADE N°3
x= 100
val = str(x)
print(val + " pontos alcançados")
# Out:
# 100 pontos alcançados

# %%
#ATIVIDADE N°4
valor= int(input("Digite 1 para verdadeiro ou 0 para falso "))
resul= bool(valor)
print(resul)
# Out:
# Digite 1 para verdadeiro ou 0 para falso 0
# False

# %%
#ATIVIDADE N°5
num1= int(input("Digite o 1° número: "))
num2= int(input("Digite o 2° numero: "))
num3= int(input("Digite o 3° numero: "))
print("O maior número dentre eles é:")
print(max(num1, num2, num3))
# Out:
# Digite o 1° número: 2
# Digite o 2° numero: 7
# Digite o 3° numero: 9
# O maior número dentre eles é:
# 9

# %%
#ATIVIDADE N°6
num1= float(input("Digite o 1° número: "))
num2= float(input("Digite o 2° numero: "))
num3= float(input("Digite o 3° numero: "))
num4= float(input("Digite o 3° numero: "))
print("A MÉDIA DOS NÚMEROS É:")
print((num1 + num2 + num3 + num4) / 4)
# Out:
# Digite o 1° número: 6
# Digite o 2° numero: 4
# Digite o 3° numero: 2
# Digite o 3° numero: 8
# A MÉDIA DOS NÚMEROS É:
# 5.0

# %%
#ATIVIDADE N°7
x= int(input("Digite sua idade:"))
print("QUANTIDADE DE MESES QUE VOCÊ JÁ VIVEU:")
print(x * 12)
# Out:
# Digite sua idade:18
# QUANTIDADE DE MESES QUE VOCÊ JÁ VIVEU:
# 216

# %%
#ATIVIDADE N°8
x= str(int(input("Digite um número:")))
print("o número digitado possui:", len(x), "caracteres")
# Out:
# Digite um número:2345678901
# o número digitado possui: 10 caracteres

# %%
#ATIVIDADE N°9
x= int(input("Digite um número inteiro:"))
print("Esse número somado a 1 é:")
print(x + 1)
# Out:
# Digite um número inteiro:5
# Esse número somado a 1 é:
# 6

# %%
#ATIVIDADE N°10
num= input("Digite um número decimal:")
num_float= float(num)
num_int= int(num_float)
print("Valor em float:", num_float)
print("Valor em inteiro:", num_int)
# Out:
# Digite um número decimal:1.2
# Valor em float: 1.2
# Valor em inteiro: 1

# %%
#ATIVIDADE N°11
num= input("Digite um número:")
num_int= int(num)
num_bool= bool(num_int)

print("Inteiro:", num_int)
print("Booleano:",(num_bool),"pois apenas valores 0 ou vazio são False em Python")
# Out:
# Digite um número:12
# Inteiro: 12
# Booleano: True pois apenas valores 0 ou vazio são False em Python

# %%
#ATIVIDADE N°12
kel= float(input("Digite a temperatura em Kelvin:"))
cel= kel - 273.15

print(f"A temperatura em graus Celsius é {cel:.2f}")
# Out:
# Digite a temperatura em Kelvin:321
# A temperatura em graus Celsius é 47.85

# %%
#ATIVIDADE N°13
nome= input("Digite seu nome completo: ")
idade= int(input("Digite sua idade: "))
salario= float(input("Digite seu salário: "))

print(f"Seu nome é {nome}, sua idade é {idade} e seu salário é {salario:.3f}")
# Out:
# Digite seu nome completo: Karen Panzeri
# Digite sua idade: 18
# Digite seu salário: 1.600
# Seu nome é Karen Panzeri, sua idade é 18 e seu salário é 1.600

# %%
#ATIVIDADE N°14
preco= float(input("Digite o preço do produto:"))
desconto= float(input("Digite o desconto em porcentagem:"))
precofinal= preco - (preco * (desconto / 100))

print(f"O preço final do produto é {precofinal:.2f}")
# Out:
# Digite o preço do produto:100
# Digite o desconto em porcentagem:12
# O preço final do produto é 88.00

# %%
#ATIVIDADE N°15
try:
  num= input("Digite um valor numérico: ")
  convertido= int(num)
  print(convertido)

except:
  print("Valor inválido")
# Out:
# Digite um valor numérico: 10.5
# Valor inválido
