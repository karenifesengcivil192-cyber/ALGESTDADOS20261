# %% [markdown]
# <a href="https://colab.research.google.com/github/karenifesengcivil192-cyber/ALGESTDADOS20261/blob/main/TESTE/2026_SEMANA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("olá mundo!!!")
# Out:
# olá mundo!!!

# %%
print("olá calouros!")
print("sejam bem-vindos!!!")
# Out:
# olá calouros!
# sejam bem-vindos!!!
